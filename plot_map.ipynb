# %%
import healpy as hp
import numpy as np

# %%
m = hp.read_map('pure_maps/B/B_map_0.fits', field=[1,2], dtype=np.float64)
hp.mollview(m[0])
# Out:
# NSIDE = 128
# ORDERING = NESTED in fits file
# INDXSCHM = IMPLICIT
# Ordering converted to RING
# Ordering converted to RING

# %%
m = hp.read_map('toast_pure_maps/0/B_telescope_all_time_all_binned.fits', field=[1,2], dtype=np.float64)
hp.mollview(m[1])
# Out:
# NSIDE = 128
# ORDERING = NESTED in fits file
# INDXSCHM = IMPLICIT
# Ordering converted to RING
# Ordering converted to RING
