# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
total = np.loadtxt('totcls.txt')
ell, TT, EE, BB, TE = np.transpose(total)

# %%
plt.plot(ell, TT, label='TT')
plt.plot(ell, EE, label='EE')
plt.plot(ell, BB, label='BB (r=0.01)')

plt.xscale('log')
plt.yscale('log')
plt.legend()

# %%
plt.plot(ell, BB)
